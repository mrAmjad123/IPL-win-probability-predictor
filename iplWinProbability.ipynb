# %%
import numpy as np
import pandas as pd

# %%
matches = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
matches.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
delivery.shape
# Out:
# (260920, 17)

# %%
total_score = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2212   1426310       2         174
# 2213   1426311       1         175
# 2214   1426311       2         139
# 2215   1426312       1         113
# 2216   1426312       2         114
#
# [2217 rows x 3 columns]

# %%
total_score_df = total_score[total_score['inning']==1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
match_df = matches.merge(total_score_df[['match_id','total_runs']],left_on='id', right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = [
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders',
    'Gujarat Titans',
    'Lucknow Super Giants',
    'Delhi Capitals',
    'Mumbai Indians',
    'Rajasthan Royals',
    'Punjab Kings',
    'Chennai Super Kings',
    'Sunrisers Hyderabad'
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab','Punjab Kings')

match_df['team1'] = match_df['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
match_df['team2'] = match_df['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match_df.shape
# Out:
# (980, 22)

# %%
match_df[['match_id','city','winner','total_runs','target_runs']]
# Out:
#       match_id        city                       winner  total_runs  \
# 0       335982   Bangalore        Kolkata Knight Riders         222
# 1       335983  Chandigarh          Chennai Super Kings         240
# 2       335984       Delhi             Delhi Daredevils         129
# 3       335985      Mumbai  Royal Challengers Bangalore         165
# 4       335986     Kolkata        Kolkata Knight Riders         110
# ...        ...         ...                          ...         ...
# 1090   1426307   Hyderabad          Sunrisers Hyderabad         214
# 1091   1426309   Ahmedabad        Kolkata Knight Riders         159
# 1092   1426310   Ahmedabad             Rajasthan Royals         172
# 1093   1426311     Chennai          Sunrisers Hyderabad         175
# 1094   1426312     Chennai        Kolkata Knight Riders         113
#
#       target_runs
# 0           223.0
# 1           241.0
# 2           130.0
# 3           166.0
# 4           111.0
# ...           ...
# ...

# %%
delivery_df = match_df.merge(delivery, on = 'match_id')

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 0        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 2        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 3        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 4        335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
delivery_df.shape
# Out:
# (233901, 38)

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.shape
# Out:
# (112805, 38)

# %%
delivery_df['total_runs_y'] = pd.to_numeric(delivery_df['total_runs_y'], errors='coerce')
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\4128596646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['total_runs_y'] = pd.to_numeric(delivery_df['total_runs_y'], errors='coerce')

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\1894988650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left'] = delivery_df['target_runs'] - delivery_df['current_score']
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\3456364349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['target_runs'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 124      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
delivery_df['valid_ball'] = ~delivery_df['extras_type'].isin(['wides', 'no-ball'])

delivery_df['valid_ball_count'] = delivery_df.groupby('match_id')['valid_ball'].cumsum()

total_balls = 120
delivery_df['balls_left'] = total_balls - delivery_df['valid_ball_count']
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\1599462593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['valid_ball'] = ~delivery_df['extras_type'].isin(['wides', 'no-ball'])
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\1599462593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['valid_ball_count'] = delivery_df.groupby('match_id')['valid_ball'].cumsum()
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\1599462593.py:6: SettingWithCopyWarning:
# ...

# %%
delivery_df.head(20)
# Out:
#          id   season       city        date match_type player_of_match  \
# 124  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 129  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 130  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 131  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 132  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 133  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 134  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 135  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets = delivery_df.groupby('match_id')['player_dismissed'].cumsum().values
delivery_df['wickets_left'] = 10 - wickets
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\4254827463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\4254827463.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# ...

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 124      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
delivery_df.tail()
# Out:
#              id season     city        date match_type player_of_match  \
# 233896  1426312   2024  Chennai  2024-05-26      Final        MA Starc
# 233897  1426312   2024  Chennai  2024-05-26      Final        MA Starc
# 233898  1426312   2024  Chennai  2024-05-26      Final        MA Starc
# 233899  1426312   2024  Chennai  2024-05-26      Final        MA Starc
# 233900  1426312   2024  Chennai  2024-05-26      Final        MA Starc
#
#                                            venue                team1  \
# 233896  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 233897  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 233898  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 233899  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 233900  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                         team2          toss_winner  ... is_wicket  \
# ...

# %%
delivery_df['crr'] = (delivery_df['current_score']*6) / (120 - delivery_df['balls_left'])
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\2136895662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr'] = (delivery_df['current_score']*6) / (120 - delivery_df['balls_left'])

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 124      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
delivery_df['rrr'] = (delivery_df['runs_left']*6) / delivery_df['balls_left']
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\1270937461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr'] = (delivery_df['runs_left']*6) / delivery_df['balls_left']

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 124      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis=1)
# Out:
# C:\Users\amjad\AppData\Local\Temp\ipykernel_40104\343102418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result, axis=1)

# %%
delivery_df
# Out:
#              id   season       city        date match_type player_of_match  \
# 124      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 125      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 126      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 127      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 128      335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# ...         ...      ...        ...         ...        ...             ...
# 233896  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233897  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233898  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233899  1426312     2024    Chennai  2024-05-26      Final        MA Starc
# 233900  1426312     2024    Chennai  2024-05-26      Final        MA Starc
#
# ...

# %%
final_df = delivery_df[['batting_team','bowling_team', 'city', 'runs_left', 'balls_left', 'wickets_left','target_runs', 'crr', 'rrr', 'result']]

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 233896        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233897        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233898        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233899        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233900        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
final_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets_left       0
# target_runs        0
# crr                0
# rrr               14
# result             0
# dtype: int64

# %%
final_df.describe()
# Out:
# C:\Users\amjad\AppData\Roaming\Python\Python312\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# C:\Users\amjad\AppData\Roaming\Python\Python312\site-packages\numpy\_core\_methods.py:53: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#            runs_left     balls_left   wickets_left    target_runs  \
# count  112805.000000  112805.000000  112805.000000  112805.000000
# mean       94.476903      62.679846       7.500740     169.278481
# std        51.145277      33.562101       2.172577      31.320127
# min       -10.000000      -4.000000       0.000000      43.000000
# 25%        54.000000      34.000000       6.000000     150.000000
# 50%        93.000000      63.000000       8.000000     169.000000
# 75%       133.000000      92.000000       9.000000     189.000000
# ...

# %%
data = final_df

# %%
data
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 233896        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233897        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233898        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233899        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233900        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
data1 = data1.replace([np.inf, -np.inf], np.nan)

# %%
data2 = final_df

# %%
print(type(data2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
final_df.describe()
# Out:
#            runs_left     balls_left   wickets_left    target_runs  \
# count  112805.000000  112805.000000  112805.000000  112805.000000
# mean       94.476903      62.679846       7.500740     169.278481
# std        51.145277      33.562101       2.172577      31.320127
# min       -10.000000      -4.000000       0.000000      43.000000
# 25%        54.000000      34.000000       6.000000     150.000000
# 50%        93.000000      63.000000       8.000000     169.000000
# 75%       133.000000      92.000000       9.000000     189.000000
# max       287.000000     120.000000      10.000000     288.000000
#
#                  crr            rrr         result
# count  112742.000000  112406.000000  112805.000000
# mean        7.638098      10.736852       0.513284
# std         2.406024      15.035763       0.499826
# min         0.000000    -516.000000       0.000000
# 25%         6.416667       7.304348       0.000000
# 50%         7.636364       9.076923       1.000000
# ...

# %%
final_df.isna().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets_left       0
# target_runs        0
# crr               63
# rrr              399
# result             0
# dtype: int64

# %%
final_df = final_df.dropna()

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 233896        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233897        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233898        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233899        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 233900        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  target_runs        crr  \
# ...

# %%
final_df.isna().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# target_runs     0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df.describe()
# Out:
#            runs_left     balls_left   wickets_left    target_runs  \
# count  106354.000000  106354.000000  106354.000000  106354.000000
# mean       94.480856      62.904639       7.515984     169.146511
# std        50.998557      33.385730       2.153440      31.470322
# min       -10.000000      -4.000000       0.000000      43.000000
# 25%        54.000000      35.000000       6.000000     149.000000
# 50%        93.000000      64.000000       8.000000     169.000000
# 75%       132.000000      92.000000       9.000000     189.000000
# max       287.000000     119.000000      10.000000     288.000000
#
#                  crr            rrr         result
# count  106354.000000  106354.000000  106354.000000
# mean        7.659192      10.662946       0.517000
# std         2.419772      14.818366       0.499713
# min         0.000000    -516.000000       0.000000
# 25%         6.428571       7.309091       0.000000
# 50%         7.653061       9.058824       1.000000
# ...

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#                 batting_team         bowling_team       city  runs_left  \
# 212835  Lucknow Super Giants  Sunrisers Hyderabad  Hyderabad      163.0
#
#         balls_left  wickets_left  target_runs       crr        rrr  result
# 212835          91             9        183.0  4.137931  10.747253       1

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 194051          Sunrisers Hyderabad  Royal Challengers Bangalore      Mumbai
# 218184  Royal Challengers Bengaluru                 Punjab Kings   Bengaluru
# 108631          Chennai Super Kings               Mumbai Indians     Kolkata
# 76596              Rajasthan Royals              Kings XI Punjab  Chandigarh
# 128512             Delhi Daredevils              Kings XI Punjab       Delhi
# ...                             ...                          ...         ...
# 179471             Rajasthan Royals        Kolkata Knight Riders     Sharjah
# 166845  Royal Challengers Bangalore               Mumbai Indians     Chennai
# 124976          Sunrisers Hyderabad               Mumbai Indians   Hyderabad
# 147842              Kings XI Punjab  Royal Challengers Bangalore   Bengaluru
# 93124              Rajasthan Royals              Kings XI Punjab  Chandigarh
#
# ...

# %%
X_train.describe()
# Out:
#           runs_left    balls_left  wickets_left   target_runs           crr  \
# count  74447.000000  74447.000000  74447.000000  74447.000000  74447.000000
# mean      94.494647     62.934692      7.514460    169.115962      7.662207
# std       50.910856     33.371981      2.157769     31.351341      2.426750
# min      -10.000000     -4.000000      0.000000     43.000000      0.000000
# 25%       54.000000     35.000000      6.000000    149.000000      6.428571
# 50%       93.000000     64.000000      8.000000    169.000000      7.653061
# 75%      132.000000     92.000000      9.000000    189.000000      8.914286
# max      287.000000    119.000000     10.000000    288.000000     54.000000
#
#                 rrr
# count  74447.000000
# mean      10.671952
# std       14.873178
# min     -516.000000
# 25%        7.293611
# 50%        9.054545
# 75%       11.257732
# max      588.000000

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer ([
    ('trf' , OneHotEncoder(sparse_output = False, drop = 'first'),['batting_team','bowling_team','city'])
]
,remainder = 'passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps = [
    ('strp1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\amjad\AppData\Roaming\Python\Python312\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('strp1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8035540790422164

# %%
pipe.predict_proba(X_test)[7]
# Out:
# array([0.3943251, 0.6056749])

# %%
#this is on no use in final prediction
def match_summary(row):
    print("Batting Team-" + row['batting_team'] + " | Bowling Team-" + row['bowling_team'] + " | Target- " + str(row['total_runs_x']))

# %%
#this is on no use in final prediction


def match_progression(x_df, match_id, pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    
    # Check the columns of the match dataframe
    print("Match Columns:", match.columns)
    
    # Ensure the 'wickets' column exists
    if 'wickets' not in match.columns:
        print("Warning: 'wickets' column is missing. Adding a default value.")
        match['wickets'] = 10  # Add a default value, adjust as necessary
    
    # Now proceed to filter and drop NaNs
    temp_df = match[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left',
                     'wickets', 'total_runs_x', 'crr', 'rrr']].dropna()
    
    # Handle missing 'target_runs' or 'wickets_left'
    if 'target_runs' not in temp_df.columns or 'wickets_left' not in temp_df.columns:
        print("Warning: Missing 'target_runs' or 'wickets_left' columns. Adding default values.")
        temp_df['target_runs'] = 200  # Example: default target value
        temp_df['wickets_left'] = 10  # Example: default wickets value
    
    # Check if temp_df is empty
    if temp_df.shape[0] == 0:
        print("No data available for prediction. Exiting.")
        return None, None
    
    # Initialize lists to store results
    results = []
    
    for i in range(temp_df.shape[0]):
        # Extract the current row
        row = temp_df.iloc[i:i+1]
        
        # Predict win/loss probability
        result = pipe.predict_proba(row)
        
        # Calculate probabilities
        lose_prob = np.round(result.T[0] * 100, 1)
        win_prob = np.round(result.T[1] * 100, 1)
        
        # Add current ball data to results
        ball_data = {
            'end_of_ball': i + 1,  # Ball number
            'runs_after_ball': row['runs_left'].values[0] - row['runs_left'].values[0] + row['total_runs_x'].values[0],  # Calculate runs after ball
            'wickets_in_ball': row['wickets'].values[0],  # Wickets left
            'lose': lose_prob[0],
            'win': win_prob[0]
        }
        
        results.append(ball_data)
    
    # Convert results to DataFrame
    result_df = pd.DataFrame(results)
    print(result_df)
    
    return result_df

# Example usage

# %%
temp_df, target = match_progression(delivery_df, 74, pipe)
if temp_df is not None:
    print(temp_df)
# Out:
# Match Columns: Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs_x', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batter', 'bowler',
#        'non_striker', 'batsman_runs', 'extra_runs', 'total_runs_y',
#        'extras_type', 'is_wicket', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'current_score', 'runs_left', 'valid_ball',
#        'valid_ball_count', 'balls_left', 'wickets_left', 'crr', 'rrr'],
#       dtype='object')
# ...
# No data available for prediction. Exiting.

# %%
teams
# Out:
# ['Royal Challengers Bengaluru',
#  'Kolkata Knight Riders',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Delhi Capitals',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
import pickle
pickle.dump(pipe, open('pipe.pkl','wb'))
